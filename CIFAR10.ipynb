# %% [markdown]
# <a href="https://colab.research.google.com/github/Selani-Indrapala/CNNs-using-tf/blob/main/CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data() #Loading dataset
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step

# %%
import matplotlib.pyplot as plt

def show_images(train_images,
            	class_names,
            	train_labels,
            	nb_samples = 12, nb_row = 4):

  plt.figure(figsize=(12, 12))
  for i in range(nb_samples):
    plt.subplot(nb_row, nb_row, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])
  plt.show()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           	'dog', 'frog', 'horse', 'ship', 'truck']

show_images(train_images, class_names, train_labels)

# %%
#Scaling data between 0 and 1
max_pixel_value = 255

train_images = train_images / max_pixel_value
test_images = test_images / max_pixel_value

# %%
#Converting labels into numerical format
from tensorflow.keras.utils import to_categorical
train_labels = to_categorical(train_labels, len(class_names))
test_labels = to_categorical(test_labels, len(class_names))

# %%
#Implementing CNN
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Variables
INPUT_SHAPE = (32, 32, 3)
FILTER1_SIZE = 32
FILTER2_SIZE = 64
FILTER_SHAPE = (3, 3)
POOL_SHAPE = (2, 2)
FULLY_CONNECT_NUM = 128
NUM_CLASSES = len(class_names)

# Model architecture implementation
model = Sequential()
model.add(Conv2D(FILTER1_SIZE, FILTER_SHAPE, activation='relu', input_shape=INPUT_SHAPE))
model.add(MaxPooling2D(POOL_SHAPE))
model.add(Conv2D(FILTER2_SIZE, FILTER_SHAPE, activation='relu'))
model.add(MaxPooling2D(POOL_SHAPE))
model.add(Flatten())
model.add(Dense(FULLY_CONNECT_NUM, activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# %%
#Training the data
from tensorflow.keras.metrics import Precision, Recall

BATCH_SIZE = 32
EPOCHS = 30

METRICS = metrics=['accuracy',
               	Precision(name='precision'),
               	Recall(name='recall')]

model.compile(optimizer='adam',
          	loss='categorical_crossentropy',
          	metrics = METRICS)

# Train the model
training_history = model.fit(train_images, train_labels,
                	epochs=EPOCHS, batch_size=BATCH_SIZE,
                	validation_data=(test_images, test_labels))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 22s 6ms/step - loss: 1.4310 - accuracy: 0.4873 - precision: 0.7063 - recall: 0.2674 - val_loss: 1.1510 - val_accuracy: 0.5922 - val_precision: 0.7418 - val_recall: 0.4205
# Epoch 2/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0492 - accuracy: 0.6340 - precision: 0.7649 - recall: 0.4915 - val_loss: 0.9945 - val_accuracy: 0.6454 - val_precision: 0.7636 - val_recall: 0.5183
# Epoch 3/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9090 - accuracy: 0.6822 - precision: 0.7917 - recall: 0.5707 - val_loss: 0.9498 - val_accuracy: 0.6738 - val_precision: 0.7747 - val_recall: 0.5713
# Epoch 4/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8105 - accuracy: 0.7173 - precision: 0.8118 - recall: 0.6256 - val_loss: 0.9082 - val_accuracy: 0.6886 - val_precision: 0.7810 - val_recall: 0.6063
# Epoch 5/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7270 - accuracy: 0.7454 - precision: 0.8265 - recall: 0.6676 - val_loss: 0.9113 - val_accuracy: 0.6906 - val_precision: 0.7717 - val_recall: 0.6185
# Epoch 6/30
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.6485 - accuracy: 0.7719 - precision: 0.8420 - recall: 0.7046 - val_loss: 0.9108 - val_accuracy: 0.6978 - val_precision: 0.7635 - val_recall: 0.6379
# Epoch 7/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5787 - accuracy: 0.7969 - precision: 0.8576 - recall: 0.7415 - val_loss: 0.9190 - val_accuracy: 0.7055 - val_precision: 0.7612 - val_recall: 0.6571
# Epoch 8/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.5157 - accuracy: 0.8183 - precision: 0.8679 - recall: 0.7708 - val_loss: 0.9377 - val_accuracy: 0.7038 - val_precision: 0.7585 - val_recall: 0.6631
# Epoch 9/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4554 - accuracy: 0.8413 - precision: 0.8826 - recall: 0.8022 - val_loss: 0.9901 - val_accuracy: 0.7013 - val_precision: 0.7464 - val_recall: 0.6609
# Epoch 10/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3960 - accuracy: 0.8603 - precision: 0.8962 - recall: 0.8277 - val_loss: 1.0667 - val_accuracy: 0.6931 - val_precision: 0.7298 - val_recall: 0.6655
# Epoch 11/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.3460 - accuracy: 0.8785 - precision: 0.9071 - recall: 0.8508 - val_loss: 1.1458 - val_accuracy: 0.6933 - val_precision: 0.7289 - val_recall: 0.6664
# Epoch 12/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.3016 - accuracy: 0.8943 - precision: 0.9165 - recall: 0.8731 - val_loss: 1.2139 - val_accuracy: 0.6880 - val_precision: 0.7168 - val_recall: 0.6660
# Epoch 13/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2526 - accuracy: 0.9119 - precision: 0.9295 - recall: 0.8959 - val_loss: 1.3189 - val_accuracy: 0.6851 - val_precision: 0.7086 - val_recall: 0.6669
# Epoch 14/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.2250 - accuracy: 0.9208 - precision: 0.9359 - recall: 0.9071 - val_loss: 1.4777 - val_accuracy: 0.6835 - val_precision: 0.7025 - val_recall: 0.6709
# Epoch 15/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1925 - accuracy: 0.9305 - precision: 0.9420 - recall: 0.9206 - val_loss: 1.4858 - val_accuracy: 0.6884 - val_precision: 0.7067 - val_recall: 0.6779
# Epoch 16/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1756 - accuracy: 0.9366 - precision: 0.9467 - recall: 0.9281 - val_loss: 1.6062 - val_accuracy: 0.6867 - val_precision: 0.7030 - val_recall: 0.6764
# Epoch 17/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1458 - accuracy: 0.9494 - precision: 0.9568 - recall: 0.9422 - val_loss: 1.7256 - val_accuracy: 0.6778 - val_precision: 0.6930 - val_recall: 0.6681
# Epoch 18/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1427 - accuracy: 0.9500 - precision: 0.9565 - recall: 0.9440 - val_loss: 1.8740 - val_accuracy: 0.6785 - val_precision: 0.6899 - val_recall: 0.6707
# Epoch 19/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1256 - accuracy: 0.9547 - precision: 0.9601 - recall: 0.9502 - val_loss: 1.9680 - val_accuracy: 0.6760 - val_precision: 0.6863 - val_recall: 0.6687
# Epoch 20/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1154 - accuracy: 0.9594 - precision: 0.9635 - recall: 0.9555 - val_loss: 2.0214 - val_accuracy: 0.6850 - val_precision: 0.6952 - val_recall: 0.6782
# Epoch 21/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.1055 - accuracy: 0.9628 - precision: 0.9666 - recall: 0.9595 - val_loss: 2.1756 - val_accuracy: 0.6754 - val_precision: 0.6852 - val_recall: 0.6690
# Epoch 22/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1057 - accuracy: 0.9623 - precision: 0.9665 - recall: 0.9598 - val_loss: 2.2311 - val_accuracy: 0.6880 - val_precision: 0.6961 - val_recall: 0.6841
# Epoch 23/30
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.0999 - accuracy: 0.9646 - precision: 0.9675 - recall: 0.9616 - val_loss: 2.2608 - val_accuracy: 0.6856 - val_precision: 0.6939 - val_recall: 0.6813
# Epoch 24/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0889 - accuracy: 0.9680 - precision: 0.9710 - recall: 0.9660 - val_loss: 2.3497 - val_accuracy: 0.6839 - val_precision: 0.6899 - val_recall: 0.6803
# Epoch 25/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0958 - accuracy: 0.9660 - precision: 0.9689 - recall: 0.9639 - val_loss: 2.4880 - val_accuracy: 0.6704 - val_precision: 0.6778 - val_recall: 0.6659
# Epoch 26/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0794 - accuracy: 0.9723 - precision: 0.9743 - recall: 0.9708 - val_loss: 2.5483 - val_accuracy: 0.6740 - val_precision: 0.6796 - val_recall: 0.6697
# Epoch 27/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0823 - accuracy: 0.9718 - precision: 0.9736 - recall: 0.9704 - val_loss: 2.6251 - val_accuracy: 0.6752 - val_precision: 0.6811 - val_recall: 0.6710
# Epoch 28/30
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0787 - accuracy: 0.9729 - precision: 0.9743 - recall: 0.9712 - val_loss: 2.5896 - val_accuracy: 0.6782 - val_precision: 0.6846 - val_recall: 0.6741
# Epoch 29/30
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0853 - accuracy: 0.9699 - precision: 0.9718 - recall: 0.9685 - val_loss: 2.7443 - val_accuracy: 0.6790 - val_precision: 0.6841 - val_recall: 0.6753
# Epoch 30/30
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.0683 - accuracy: 0.9766 - precision: 0.9781 - recall: 0.9756 - val_loss: 2.8278 - val_accuracy: 0.6761 - val_precision: 0.6821 - val_recall: 0.6732

# %%
import numpy as np

def show_performance_curve(training_result, metric, metric_label):

	train_perf = training_result.history[str(metric)]
	validation_perf = training_result.history['val_'+str(metric)]
	intersection_idx = np.argwhere(np.isclose(train_perf,
                                            	validation_perf, atol=1e-2)).flatten()[0]
	intersection_value = train_perf[intersection_idx]

	plt.plot(train_perf, label=metric_label)
	plt.plot(validation_perf, label = 'val_'+str(metric))
	plt.axvline(x=intersection_idx, color='r', linestyle='--', label='Intersection')

	plt.annotate(f'Optimal Value: {intersection_value:.4f}',
         	xy=(intersection_idx, intersection_value),
         	xycoords='data',
         	fontsize=10,
         	color='green')

	plt.xlabel('Epoch')
	plt.ylabel(metric_label)
	plt.legend(loc='lower right')

# %%
show_performance_curve(training_history, 'accuracy', 'accuracy')

# %%
show_performance_curve(training_history, 'precision', 'precision')

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

test_predictions = model.predict(test_images)

test_predicted_labels = np.argmax(test_predictions, axis=1)

test_true_labels = np.argmax(test_labels, axis=1)

cm = confusion_matrix(test_true_labels, test_predicted_labels)

cmd = ConfusionMatrixDisplay(confusion_matrix=cm)

cmd.plot(include_values=True, cmap='viridis', ax=None, xticks_rotation='horizontal')
plt.show()
# Out:
# 313/313 [==============================] - 2s 4ms/step
